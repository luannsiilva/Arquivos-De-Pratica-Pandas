# %%
# Importação do pandas com IMPORT e AS
import pandas as pd

# Leitura dos arquivos, utilização do SEP para visualização e formatação do código com ENCODING
produtos_df = pd.read_csv('Contoso - Cadastro Produtos.csv', sep=';', encoding='ISO-8859-1')
clientes_df = pd.read_csv('Contoso - Clientes.csv', sep=';', encoding='ISO-8859-1')
lojas_df = pd.read_csv('Contoso - Lojas.csv', sep=';', encoding='ISO-8859-1')
vendas_df = pd.read_csv('Contoso - Vendas - 2017.csv', sep=';', encoding='ISO-8859-1')

display(produtos_df[:2])
display(clientes_df[:2])
display(lojas_df[:2])
display(vendas_df[:2])
# Out:
#                                 ÿNome do Produto  \
# 0          Contoso Wireless Laser Mouse E50 Grey
# 1  Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
#
#                                 Descricao do Produto    Fabricante  \
# 0  Advanced 2.4 GHz cordless technology makes fre...  Contoso, Ltd
# 1                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
#
#   Nome da Marca       Tipo Custo Unitario Preco Unitario  ID Produto  \
# 0       Contoso  Econômico          10,69          20,96         873
# 1       Contoso  Econômico           6,63             13         879
#
#    ID Subcategoria
# 0               22
# 1               22
#    ÿID Cliente Primeiro Nome   Sobrenome                       E-mail  \
# 0            1        Garnet  Lanfranchi  glanfranchi0@mayoclinic.com
# 1            2       Lurette   Roseblade    lroseblade1@bigcartel.com
#
#      Genero  Numero de Filhos Data de Nascimento  Unnamed: 7  Unnamed: 8  \
# ...

# %%
# Renomeação dos nomes das colunas com RENAME e especificação das colunas com COLUMNS e inserção dentro do arquivo com INPLACE
produtos_df.rename(columns={'ÿNome do Produto': 'Nome do Produto'}, inplace=True)
clientes_df.rename(columns={'ÿID Cliente': 'ID Cliente'}, inplace=True)
lojas_df.rename(columns={'ÿID Loja': 'ID Loja'}, inplace=True)

display(produtos_df[:2])
display(clientes_df[:2])
display(lojas_df[:2])
# Out:
#                                  Nome do Produto  \
# 0          Contoso Wireless Laser Mouse E50 Grey
# 1  Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
#
#                                 Descricao do Produto    Fabricante  \
# 0  Advanced 2.4 GHz cordless technology makes fre...  Contoso, Ltd
# 1                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
#
#   Nome da Marca       Tipo Custo Unitario Preco Unitario  ID Produto  \
# 0       Contoso  Econômico          10,69          20,96         873
# 1       Contoso  Econômico           6,63             13         879
#
#    ID Subcategoria
# 0               22
# 1               22
#    ID Cliente Primeiro Nome   Sobrenome                       E-mail  \
# 0           1        Garnet  Lanfranchi  glanfranchi0@mayoclinic.com
# 1           2       Lurette   Roseblade    lroseblade1@bigcartel.com
#
#      Genero  Numero de Filhos Data de Nascimento  Unnamed: 7  Unnamed: 8  \
# ...

# %%
# removendo colunas desnecessárias
clientes_df.drop(['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], axis=1)

display(clientes_df[:5])
# Out:
#    ID Cliente Primeiro Nome     Sobrenome                       E-mail  \
# 0           1        Garnet    Lanfranchi  glanfranchi0@mayoclinic.com
# 1           2       Lurette     Roseblade    lroseblade1@bigcartel.com
# 2           3       Glenden     Ishchenko    gishchenko2@moonfruit.com
# 3           4         Baron  Jedrzejewsky  bjedrzejewsky3@e-recht24.de
# 4           5        Sheree      Bredbury     sbredbury4@sitemeter.com
#
#       Genero  Numero de Filhos Data de Nascimento  Unnamed: 7  Unnamed: 8  \
# 0   Feminino                 2         12/05/1995         NaN         NaN
# 1   Feminino                 2         30/06/1943         NaN         NaN
# 2  Masculino                 5         09/04/1989         NaN         NaN
# 3  Masculino                 4         17/11/1998         NaN         NaN
# 4   Feminino                 5         08/09/1975         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10
# 0         NaN          NaN
# 1         NaN          NaN
# ...

# %%
# Selecionando apenas as colunas necessárias para a análise
produtos_df = produtos_df[['Nome do Produto', 'ID Produto']]
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
lojas_df = lojas_df[['Nome da Loja', 'ID Loja']]

display(produtos_df[:2])
display(clientes_df[:2])
display(lojas_df[:2])
# Out:
#                                  Nome do Produto  ID Produto
# 0          Contoso Wireless Laser Mouse E50 Grey         873
# 1  Contoso Optical Wheel OEM PS/2 Mouse E60 Grey         879
#    ID Cliente                       E-mail
# 0           1  glanfranchi0@mayoclinic.com
# 1           2    lroseblade1@bigcartel.com
#                  Nome da Loja  ID Loja
# 0  Loja Contoso Seattle No.1         1
# 1  Loja Contoso Seattle No.2         2

# %%
# Mesclando as informações com o MARGE e especificando qual coluna será mesclada com ON
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')

# %%
display(vendas_df[:5])
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1                2    01/01/2017    06/01/2017         5      308        1586
# 2                3    01/01/2017    01/01/2017         0      294        1444
# 3                4    01/01/2017    01/01/2017         0      251        1468
# 4                5    01/01/2017    07/01/2017         6       94        1106
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1            2       18469                   9                     1
# 2            5       19730                  13                     1
# 3            5       29326                   6                     1
# 4            2       22617                   4                     1
#
#                                      Nome do Produto  \
# ...
